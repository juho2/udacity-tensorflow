# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'originated', 'anarchism', 'term', 'originated', 'term', 'of', 'as']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.101986
# Nearest to called: boasted, snl, plunge, fdp, echelon, motorised, ethylene, cryptanalysis,
# Nearest to united: mandalay, contraction, crook, supposedly, cloned, supervised, pooling, ashmore,
# Nearest to these: limitations, fernando, quiver, jimmy, thermotropic, constraint, masjid, melancholic,
# Nearest to UNK: mans, alcaeus, cosimo, cowpox, hadad, zebulon, locations, abram,
# Nearest to be: quartier, septicemic, elitism, remote, hypothetically, abijah, outlandish, astounding,
# Nearest to six: seized, margherita, shelton, statute, polished, dakota, wetter, connector,
# Nearest to five: refered, blackpool, hardships, letterboxing, receptors, yap, dist, felons,
# Nearest to s: aquarists, flamsteed, ramp, balances, guinevere, lomography, westphalia, joanne,
# Nearest to who: projecting, whirl, catharine, mice, plato, absolutist, cartier, manipulates,
# Nearest to and: fermion, zechs, obey, elves, bohemians, duals, grabbed, segregationist,
# Nearest to b: resolver, klaus, cafes, nizam, packages, raiding, rotting, vanishes,
# Nearest to were: conserved, tilt, lamo, atalh, downward, bournemouth, autoimmune, decrees,
# Nearest to over: worthies, valves, satisfiability, hornet, adolfo, countryside, nadu, fireworks,
# Nearest to after: deadly, grappelli, shipyards, jaroslav, tricity, scumm, windsor, traffic,
# Nearest to will: petrochemicals, bleach, asia, fatal, bayreuth, standoff, eum, twayne,
# Nearest to i: frac, reading, pushkin, ouster, bembo, armies, ieee, asw,
# Average loss at step 2000: 4.373550
# Average loss at step 4000: 3.871704
# Average loss at step 6000: 3.791261
# Average loss at step 8000: 3.688165
# Average loss at step 10000: 3.616989
# Nearest to called: veterans, snl, ethylene, echelon, mallet, angli, motorised, sulla,
# Nearest to united: contraction, mandalay, ashmore, same, ulrich, cloned, crook, bombed,
# Nearest to these: limitations, some, subtract, westminster, eon, thermotropic, ton, donnelly,
# Nearest to UNK: banshee, scorn, arb, historian, counselor, cinq, metalwork, moria,
# Nearest to be: have, been, due, is, by, precautions, were, kibo,
# Nearest to six: eight, seven, four, five, nine, three, zero, two,
# Nearest to five: seven, eight, four, six, nine, three, zero, two,
# Nearest to s: his, ramp, and, downright, viennese, glorify, fostered, corinne,
# Nearest to who: ptr, he, which, stuart, projecting, not, nullify, catharine,
# Nearest to and: or, in, s, maria, of, he, colecovision, austrian,
# Nearest to b: resolver, retro, unplanned, respond, mutt, cafes, discerned, unopposed,
# Nearest to were: are, was, have, had, but, be, novarum, genovese,
# Nearest to over: zeros, ctrl, hornet, countryside, persian, operands, adolfo, valves,
# Nearest to after: during, deadly, at, before, membered, persecuted, mathieu, syllables,
# Nearest to will: petrochemicals, bleach, would, can, may, again, should, sprout,
# Nearest to i: we, r, reading, pushkin, primal, hurl, oliva, limitation,
# Average loss at step 12000: 3.603613
# Average loss at step 14000: 3.567187
# Average loss at step 16000: 3.411711
# Average loss at step 18000: 3.448196
# Average loss at step 20000: 3.541092
# Nearest to called: snl, sulla, erik, veterans, ethylene, echelon, leo, mallet,
# Nearest to united: same, contraction, ashmore, ulrich, stables, mandalay, crook, cloned,
# Nearest to these: some, many, limitations, all, subtract, the, which, eon,
# Nearest to UNK: liouville, jabber, scorned, tame, nissan, mensch, repositories, essentials,
# Nearest to be: have, is, been, were, was, sweating, by, being,
# Nearest to six: eight, seven, five, four, nine, three, two, zero,
# Nearest to five: six, eight, four, three, seven, zero, two, nine,
# Nearest to s: ramp, gestalt, microorganism, pathogenic, purchasing, storyteller, corinne, desilu,
# Nearest to who: he, which, ptr, they, also, documentaries, euro, not,
# Nearest to and: or, but, doppler, judaica, from, hydrodynamic, korner, dct,
# Nearest to b: d, companion, retro, curium, intersections, donated, ecclesiology, respond,
# Nearest to were: are, had, was, have, be, emigrants, is, chancellors,
# Nearest to over: persian, about, moulds, zeros, irv, catholics, affirm, operands,
# Nearest to after: during, before, from, nantucket, while, deadly, at, membered,
# Nearest to will: can, would, may, should, petrochemicals, could, bleach, cannot,
# Nearest to i: we, iii, r, ii, pushkin, limitation, pegged, wondered,
# Average loss at step 22000: 3.503857
# Average loss at step 24000: 3.484682
# Average loss at step 26000: 3.484136
# Average loss at step 28000: 3.481003
# Average loss at step 30000: 3.506937
# Nearest to called: sulla, erik, echelon, ethylene, veterans, leo, named, paige,
# Nearest to united: same, contraction, ulrich, ashmore, mandalay, stables, crook, bombed,
# Nearest to these: some, many, all, limitations, their, they, such, which,
# Nearest to UNK: assoc, admirer, jtc, essentials, treatments, scorned, sauer, csc,
# Nearest to be: been, have, was, sweating, is, were, refer, scuttled,
# Nearest to six: eight, seven, four, five, nine, three, zero, two,
# Nearest to five: four, seven, six, three, eight, nine, zero, two,
# Nearest to s: ramp, his, intoxicated, illiberal, kerguelen, pathogenic, gruesome, debating,
# Nearest to who: he, which, they, ptr, she, and, also, there,
# Nearest to and: or, but, judaica, of, in, refugee, who, gets,
# Nearest to b: d, curium, respond, dab, sega, channing, inches, companion,
# Nearest to were: are, was, have, had, by, be, emigrants, chancellors,
# Nearest to over: about, catholics, affirm, into, irv, around, assist, overwhelmingly,
# Nearest to after: during, before, when, from, while, through, at, deadly,
# Nearest to will: would, can, may, should, could, must, might, cannot,
# Nearest to i: iii, ii, we, r, you, pegged, mor, they,
# Average loss at step 32000: 3.498902
# Average loss at step 34000: 3.493362
# Average loss at step 36000: 3.451051
# Average loss at step 38000: 3.305668
# Average loss at step 40000: 3.426570
# Nearest to called: named, considered, used, erik, amt, swung, sulla, forbes,
# Nearest to united: contraction, same, ulrich, southern, crook, ashmore, stables, western,
# Nearest to these: many, some, such, different, several, their, all, both,
# Nearest to UNK: b, polarized, pearson, sarin, benchmark, victorian, vec, j,
# Nearest to be: have, been, sweating, was, refer, were, is, are,
# Nearest to six: four, eight, seven, five, nine, three, two, one,
# Nearest to five: seven, four, six, three, eight, nine, zero, two,
# Nearest to s: ramp, downright, his, fostered, promulgation, your, imre, did,
# Nearest to who: he, which, ptr, often, she, also, that, they,
# Nearest to and: or, but, in, however, ihra, instinctively, hitherto, while,
# Nearest to b: d, UNK, inches, arion, r, c, grunwald, j,
# Nearest to were: are, have, was, had, been, be, crowning, chancellors,
# Nearest to over: about, around, into, irv, nearly, affirm, catholics, monty,
# Nearest to after: before, during, when, while, through, under, from, lipsius,
# Nearest to will: can, would, may, should, could, must, might, cannot,
# Nearest to i: ii, we, you, iii, t, they, he, wondered,
# Average loss at step 42000: 3.437310
# Average loss at step 44000: 3.455868
# Average loss at step 46000: 3.450000
# Average loss at step 48000: 3.352953
# Average loss at step 50000: 3.380261
# Nearest to called: named, erik, swung, used, wrist, forbes, mermaid, like,
# Nearest to united: contraction, ulrich, same, southern, ashmore, crook, xxxix, bombed,
# Nearest to these: some, many, both, such, several, different, those, various,
# Nearest to UNK: topol, benn, narnia, bronson, scorned, phanerozoic, countercultural, grande,
# Nearest to be: have, been, was, become, being, were, sweating, refer,
# Nearest to six: eight, seven, four, five, three, nine, two, one,
# Nearest to five: six, four, seven, three, eight, nine, zero, two,
# Nearest to s: ramp, illiberal, colbert, centennial, gestalt, intoxicated, faceted, and,
# Nearest to who: he, which, she, there, they, ptr, stuart, also,
# Nearest to and: or, but, of, however, while, hardline, belgian, s,
# Nearest to b: d, r, arion, inches, c, n, cannae, h,
# Nearest to were: are, have, had, was, been, be, those, chancellors,
# Nearest to over: around, affirm, catholics, nearly, overwhelmingly, about, monty, through,
# Nearest to after: before, during, when, while, through, under, upon, at,
# Nearest to will: would, can, should, could, may, must, might, cannot,
# Nearest to i: we, ii, iii, you, g, r, wondered, pineal,
# Average loss at step 52000: 3.433150
# Average loss at step 54000: 3.426716
# Average loss at step 56000: 3.431639
# Average loss at step 58000: 3.399548
# Average loss at step 60000: 3.393792
# Nearest to called: named, used, considered, wrist, known, dickie, taxpayer, mermaid,
# Nearest to united: contraction, ulrich, same, southern, british, heijenoort, xxxix, crook,
# Nearest to these: some, many, both, several, those, such, which, all,
# Nearest to UNK: admirer, tropes, metellus, othniel, ingested, et, lorry, ash,
# Nearest to be: been, sweating, is, become, was, produce, refer, have,
# Nearest to six: eight, five, four, seven, nine, three, two, zero,
# Nearest to five: four, six, three, eight, seven, nine, zero, two,
# Nearest to s: illiberal, gestalt, ramp, clearances, does, debating, ffffff, levitation,
# Nearest to who: he, which, she, that, they, still, ptr, stuart,
# Nearest to and: or, but, while, than, mallet, although, however, including,
# Nearest to b: d, r, c, arion, m, inches, staffordshire, n,
# Nearest to were: are, was, have, had, been, those, including, chancellors,
# Nearest to over: around, through, about, affirm, nearly, into, overwhelmingly, catholics,
# Nearest to after: before, during, while, when, despite, under, following, upon,
# Nearest to will: would, can, should, may, could, must, cannot, might,
# Nearest to i: ii, we, iii, you, they, t, r, wondered,
# Average loss at step 62000: 3.239443
# Average loss at step 64000: 3.254927
# Average loss at step 66000: 3.399527
# Average loss at step 68000: 3.395032
# Average loss at step 70000: 3.354786
# Nearest to called: named, considered, taxpayer, used, mermaid, whitaker, wrist, known,
# Nearest to united: ulrich, same, contraction, afb, crook, xxxix, heijenoort, following,
# Nearest to these: such, many, some, those, several, are, the, which,
# Nearest to UNK: h, divers, accumulates, ascetical, marquette, mystics, elsie, fichte,
# Nearest to be: been, have, is, become, being, were, was, refer,
# Nearest to six: eight, five, four, seven, nine, three, two, zero,
# Nearest to five: six, four, three, seven, nine, eight, zero, two,
# Nearest to s: ramp, fostered, whose, illiberal, intoxicated, gestalt, microorganism, pathogenic,
# Nearest to who: which, he, they, still, actually, she, binaries, guerilla,
# Nearest to and: or, but, while, however, which, of, than, turbine,
# Nearest to b: d, r, c, staffordshire, n, f, h, p,
# Nearest to were: are, was, have, had, be, emigrants, been, including,
# Nearest to over: around, through, about, nearly, tee, affirm, differing, monty,
# Nearest to after: before, during, despite, while, when, at, following, upon,
# Nearest to will: would, can, could, should, may, must, cannot, might,
# Nearest to i: ii, we, you, iii, g, r, t, hurl,
# Average loss at step 72000: 3.374104
# Average loss at step 74000: 3.349337
# Average loss at step 76000: 3.322883
# Average loss at step 78000: 3.350133
# Average loss at step 80000: 3.375949
# Nearest to called: named, considered, used, known, referred, taxpayer, swung, paige,
# Nearest to united: contraction, same, following, ulrich, afb, globe, crook, heijenoort,
# Nearest to these: many, several, such, those, some, various, certain, are,
# Nearest to UNK: smith, martin, l, novelist, wilson, h, e, divers,
# Nearest to be: been, being, have, become, is, sweating, are, produce,
# Nearest to six: five, four, eight, seven, three, nine, two, one,
# Nearest to five: six, four, seven, eight, three, nine, zero, two,
# Nearest to s: ramp, syntactically, debating, pathogenic, v, whose, desilu, circumscribed,
# Nearest to who: actually, he, she, which, still, they, never, binaries,
# Nearest to and: or, but, including, while, troubadors, shaw, superconducting, kh,
# Nearest to b: d, c, r, staffordshire, inches, gurion, curium, roy,
# Nearest to were: are, was, had, have, emigrants, been, became, dissociatives,
# Nearest to over: around, about, through, nearly, tee, quinlan, affirm, monty,
# Nearest to after: before, during, despite, when, while, following, upon, until,
# Nearest to will: would, can, could, should, must, may, cannot, might,
# Nearest to i: ii, we, iii, you, r, t, pineal, g,
# Average loss at step 82000: 3.407588
# Average loss at step 84000: 3.408953
# Average loss at step 86000: 3.391671
# Average loss at step 88000: 3.351508
# Average loss at step 90000: 3.361658
# Nearest to called: named, considered, used, referred, known, taxpayer, played, eda,
# Nearest to united: contraction, afb, following, globe, ulrich, same, crook, southern,
# Nearest to these: many, several, some, are, such, certain, various, those,
# Nearest to UNK: bookshop, paternity, serge, norway, adams, ash, cq, thermally,
# Nearest to be: being, been, was, is, become, sweating, have, refer,
# Nearest to six: eight, seven, four, five, nine, three, two, zero,
# Nearest to five: four, eight, seven, three, six, nine, two, zero,
# Nearest to s: debating, pathogenic, his, gestalt, whose, ramp, illiberal, her,
# Nearest to who: he, which, often, also, she, never, they, actually,
# Nearest to and: or, but, while, toward, including, however, mallet, triples,
# Nearest to b: d, r, c, staffordshire, j, inches, mallory, h,
# Nearest to were: are, was, had, have, while, although, been, these,
# Nearest to over: around, through, nearly, about, off, within, tee, differing,
# Nearest to after: before, during, despite, while, until, upon, when, following,
# Nearest to will: would, could, can, must, should, may, might, cannot,
# Nearest to i: we, iii, ii, you, r, g, t, they,
# Average loss at step 92000: 3.398227
# Average loss at step 94000: 3.254696
# Average loss at step 96000: 3.354847
# Average loss at step 98000: 3.243992
# Average loss at step 100000: 3.357912
# Nearest to called: named, used, considered, referred, known, paige, taxpayer, jacobins,
# Nearest to united: southern, contraction, afb, ulrich, following, commonwealth, heijenoort, globe,
# Nearest to these: several, many, some, various, such, different, certain, all,
# Nearest to UNK: jtc, falkirk, guillaume, spartan, van, pepin, accolades, broadest,
# Nearest to be: been, being, sweating, are, become, is, have, easily,
# Nearest to six: seven, four, eight, five, nine, three, two, zero,
# Nearest to five: seven, six, four, eight, three, nine, two, zero,
# Nearest to s: whose, his, my, kerguelen, debating, and, klux, henning,
# Nearest to who: he, never, she, still, also, binaries, actually, uninterested,
# Nearest to and: or, but, while, like, however, including, when, although,
# Nearest to b: d, staffordshire, mara, c, fibreglass, enthroned, dmt, curium,
# Nearest to were: are, was, have, these, had, including, although, be,
# Nearest to over: around, through, nearly, about, differing, almost, within, lovin,
# Nearest to after: before, during, despite, when, following, while, until, through,
# Nearest to will: would, could, must, can, should, may, might, cannot,
# Nearest to i: we, ii, you, iii, g, t, v, they,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
